# %% [markdown]
# ![Nuclio logo](https://nuclio.school/wp-content/uploads/2018/12/nucleoDS-newBlack.png)

# %% [markdown]
# ## 1. Libraries
#
# To start, let's load those libraries that we need

# %%
from tensorflow import keras as ks
from matplotlib import pyplot as plt
import numpy as np
import time
import datetime
import random
import pandas as pd
import os
from tensorflow.keras.layers import BatchNormalization
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.callbacks import EarlyStopping

import sys
from keras.layers import Dropout
from keras.layers import BatchNormalization

# %% [markdown]
# ## 2. Model network architecture

# %% [markdown]
# # Model#1

# %% [markdown]
# this model consists of dual layer of convolution with batch normelization and max pooling which is refiniging the data before we tranfer it to our dual fully connected layers in which we are using droput method to make the model more efficent.

# %%
# 80% accurecy model on Addam
model = ks.Sequential()

model.add(ks.layers.Conv2D(64, (3, 3), strides=1, activation='relu', 
                           padding='same', input_shape=(32,32,3)))
model.add(BatchNormalization())
model.add(ks.layers.Conv2D(64, (3, 3), strides=1, activation='relu', 
                           padding='same'))
model.add(BatchNormalization())
model.add(ks.layers.MaxPooling2D((2, 2)))



model.add(ks.layers.Conv2D(64, (3, 3), strides=1, activation='relu', 
                           padding='same'))
model.add(BatchNormalization())
model.add(ks.layers.Conv2D(64, (3, 3), strides=1, activation='relu', 
                           padding='same'))
model.add(BatchNormalization())
model.add(ks.layers.MaxPooling2D((2, 2)))


model.add(ks.layers.Conv2D(64, (3, 3), strides=1, activation='relu', 
                           padding='same'))
model.add(BatchNormalization())
model.add(ks.layers.Conv2D(64, (3, 3), strides=1, activation='relu', 
                           padding='same'))
model.add(BatchNormalization())
model.add(ks.layers.MaxPooling2D((2, 2)))



model.add(ks.layers.Flatten())
model.add(ks.layers.Dropout(0.3))
model.add(ks.layers.Dense(512, activation='relu'))
#BatchNormalization()
model.add(ks.layers.Dense(512, activation='relu'))
#BatchNormalization()
model.add(ks.layers.Dropout(0.3))
model.add(ks.layers.Dense(10, activation='softmax'))

# %% [markdown]
# # Model#2

# %% [markdown]
# this model consists of single layer of convolution and max pooling which is refiniging the data(but not that much) before we tranfer it to our dual fully connected layers in which we are using droput method to make the model more efficent.

# %%
# 73.6% accurecy model on Addam
model = ks.Sequential()

model.add(ks.layers.Conv2D(64, (3, 3), strides=1, activation='relu', 
                           padding='same', input_shape=(32,32,3)))
model.add(ks.layers.MaxPooling2D((2, 2)))

model.add(ks.layers.Conv2D(64, (3, 3), strides=1, activation='relu', 
                           padding='same', input_shape=(32,32,3)))
model.add(ks.layers.MaxPooling2D((2, 2)))

model.add(ks.layers.Conv2D(64, (3, 3), strides=1, activation='relu', 
                           padding='same', input_shape=(32,32,3)))
model.add(ks.layers.MaxPooling2D((2, 2)))

model.add(ks.layers.Flatten())
model.add(ks.layers.Dropout(0.3))
model.add(ks.layers.Dense(512, activation='relu'))
model.add(ks.layers.Dense(512, activation='relu'))
model.add(ks.layers.Dropout(0.3))
model.add(ks.layers.Dense(10, activation='softmax'))

# %% [markdown]
# # Model#3

# %% [markdown]
# this model consists of dual layer of convolution with batch normelization and max pooling which is refiniging the data before we tranfer it to our singal fully connected layers in which we are using droput method to make the model more efficent.

# %%
# 80% Accurecy on Addam
model = ks.Sequential()

model.add(ks.layers.Conv2D(32, (3, 3), strides=1, activation='relu', 
                           padding='same', input_shape=(32,32,3)))
model.add(BatchNormalization())
model.add(ks.layers.Conv2D(32, (3, 3), strides=1, activation='relu', 
                           padding='same'))
model.add(BatchNormalization())
model.add(ks.layers.MaxPooling2D((2, 2)))



model.add(ks.layers.Conv2D(64, (3, 3), strides=1, activation='relu', 
                           padding='same'))
model.add(BatchNormalization())
model.add(ks.layers.Conv2D(64, (3, 3), strides=1, activation='relu', 
                           padding='same'))
model.add(BatchNormalization())
model.add(ks.layers.MaxPooling2D((2, 2)))


model.add(ks.layers.Conv2D(128, (3, 3), strides=1, activation='relu', 
                           padding='same'))
model.add(BatchNormalization())
model.add(ks.layers.Conv2D(128, (3, 3), strides=1, activation='relu', 
                           padding='same'))
model.add(BatchNormalization())
model.add(ks.layers.MaxPooling2D((2, 2)))



model.add(ks.layers.Flatten())
model.add(ks.layers.Dense(512, activation='relu'))
model.add(ks.layers.Dropout(0.5))
model.add(ks.layers.Dense(10, activation='softmax'))

# %% [markdown]
# # Model#4

# %% [markdown]
# this is a rather simple model with consists of two convolution & maxpooling layers with a single dense layer. we can see that as this model is not that complex so it gives us a very bad accurecy.

# %%
# 69% Accurecy on addam
model = ks.Sequential()

model.add(ks.layers.Conv2D(64, (3, 3), strides=1, activation='relu', 
                           padding='same', input_shape=(32,32,3)))
model.add(ks.layers.MaxPooling2D((2, 2)))

model.add(ks.layers.Conv2D(64, (3, 3), strides=1, activation='relu', 
                           padding='same'))
model.add(ks.layers.Conv2D(64, (3, 3), strides=1, activation='relu', 
                           padding='same'))

model.add(ks.layers.Flatten())
model.add(ks.layers.Dense(64, activation='relu'))
model.add(ks.layers.Dense(64, activation='softmax'))

# %% [markdown]
# # Model#5

# %% [markdown]
# In this model with triple convolution and maxpooling we are also using dropout function to observe if it makes our model efficent but unfortunatly it is stll not 80%.

# %%
# 77% accurecy on Addam
model = ks.Sequential()

model.add(ks.layers.Conv2D(32, (3, 3), strides=1, activation='relu', 
                           padding='same', input_shape=(32,32,3)))
model.add(ks.layers.Conv2D(32, (3, 3), strides=1, activation='relu', 
                           padding='same'))
model.add(ks.layers.MaxPooling2D((2, 2)))
model.add(ks.layers.Dropout(0.2))


model.add(ks.layers.Conv2D(64, (3, 3), strides=1, activation='relu', 
                           padding='same'))
model.add(ks.layers.Conv2D(64, (3, 3), strides=1, activation='relu', 
                           padding='same'))
model.add(ks.layers.MaxPooling2D((2, 2)))
model.add(ks.layers.Dropout(0.2))


model.add(ks.layers.Conv2D(128, (3, 3), strides=1, activation='relu', 
                           padding='same'))
model.add(ks.layers.Conv2D(128, (3, 3), strides=1, activation='relu', 
                           padding='same'))
model.add(ks.layers.MaxPooling2D((2, 2)))
model.add(ks.layers.Dropout(0.2))



model.add(ks.layers.Flatten())
model.add(ks.layers.Dense(512, activation='relu'))
model.add(ks.layers.Dropout(0.2))
model.add(ks.layers.Dense(10, activation='softmax'))

# %% [markdown]
# To review a model, we just have to call the **.Summary()** method of the model

# %%
model.summary()
# Out:
# Model: "sequential_9"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_48 (Conv2D)          (None, 32, 32, 64)        1792
#
#  batch_normalization_36 (Bat  (None, 32, 32, 64)       256
#  chNormalization)
#
#  conv2d_49 (Conv2D)          (None, 32, 32, 64)        36928
#
#  batch_normalization_37 (Bat  (None, 32, 32, 64)       256
#  chNormalization)
#
#  max_pooling2d_25 (MaxPoolin  (None, 16, 16, 64)       0
#  g2D)
#
#  conv2d_50 (Conv2D)          (None, 16, 16, 64)        36928
#
#  batch_normalization_38 (Bat  (None, 16, 16, 64)       256
#  chNormalization)
#
#  conv2d_51 (Conv2D)          (None, 16, 16, 64)        36928
#
#  batch_normalization_39 (Bat  (None, 16, 16, 64)       256
#  chNormalization)
#
#  max_pooling2d_26 (MaxPoolin  (None, 8, 8, 64)         0
#  g2D)
#
#  conv2d_52 (Conv2D)          (None, 8, 8, 64)          36928
#
#  batch_normalization_40 (Bat  (None, 8, 8, 64)         256
#  chNormalization)
#
#  conv2d_53 (Conv2D)          (None, 8, 8, 64)          36928
#
#  batch_normalization_41 (Bat  (None, 8, 8, 64)         256
#  chNormalization)
#
#  max_pooling2d_27 (MaxPoolin  (None, 4, 4, 64)         0
#  g2D)
#
#  flatten_9 (Flatten)         (None, 1024)              0
#
#  dropout_17 (Dropout)        (None, 1024)              0
#
#  dense_24 (Dense)            (None, 512)               524800
#
#  dense_25 (Dense)            (None, 512)               262656
#
#  dropout_18 (Dropout)        (None, 512)               0
#
#  dense_26 (Dense)            (None, 10)                5130
#
# =================================================================
# Total params: 980,554
# Trainable params: 979,786
# Non-trainable params: 768
# _________________________________________________________________

# %% [markdown]
# ## 3. Optimizer, error function

# %% [markdown]
# below we will be using two different optimizers i.e. Adam & SGD and see if using different compilers will give us improved results or not.

# %%
# Gives 80% accurecy for model 1 &3
model.compile(optimizer='Adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

# %%
# gives 79% accurecy
model.compile(optimizer='SGD',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

# %% [markdown]
# ## 4. We prepare the data
#
# We load the CIFAR10 data from the datasets directly from the Keras libraries. These are already ready in train and test
#
# **Important detail:**
# > The neural network requires that the inputs be real numbers, and we will do it by forcing the division of the values ​​within the 28x28 matrices (which have values​​ from 0 to 255) by 255.0 (a real)

# %%
cifar10 = ks.datasets.cifar10

(x_train, y_train), (x_test, y_test) = cifar10.load_data()

x_train, x_test = x_train / 255.0, x_test / 255.0
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170500096/170498071 [==============================] - 2s 0us/step
# 170508288/170498071 [==============================] - 2s 0us/step

# %%
y_train_label = y_train

# %% [markdown]
# We obtain an array with all the labels of CIFAR10

# %%
cifar10_labels = [
'airplane', # id 0
'automobile',
'bird',
'cat',
'deer',
'dog',
'frog',
'horse',
'ship',
'truck',
]

print('Number of labels: %s' % len(cifar10_labels))
# Out:
# Number of labels: 10

# %% [markdown]
# Let's paint a sample of the images from the CIFAR10 dataset, to see if it looks anything like what we expect.
# First, we see what types of data I have, then we map those arrays in a grayscale using the **. Get_cmap ()** method of PlotLy with the first nine numbers of the dataset.

# %%
# Lets paint a sample of the images of MNIST

print('Train: X=%s, y=%s' % (x_train.shape, y_train.shape))
print('Test: X=%s, y=%s' % (x_test.shape, y_test.shape))

for i in range(9):

    plt.subplot(330 + 1 + i)
    plt.imshow(x_train[i], cmap=plt.get_cmap('gray'))
    plt.title(cifar10_labels[y_train_label[i,0]])

plt.subplots_adjust(hspace = 1)
plt.show()
# Out:
# Train: X=(50000, 32, 32, 3), y=(50000, 1)
# Test: X=(10000, 32, 32, 3), y=(10000, 1)

# %% [markdown]
# We are we going to want to validate while we train (very practical)

# %%
x_val = x_train[-10000:]
y_val = y_train[-10000:]

x_train = x_train[:-10000]
y_train = y_train[:-10000]

# %%
x_train[0].shape
# Out:
# (32, 32, 3)

# %% [markdown]
# When we add convolutions, we need to "pre-treat the data", because **the convolution expects an array of 4 fields** (more like "images"), in the case of MNIST. CIFAR10 already has the right shape, so we don't have to do anything, but as we always say: you better check its size.
#
# Therefore, when exiting the Convolution, you have to do a Flatten, because FullDense layers expect arrays, not matrices !!
#
# Then we print it to see that everything is correct

# %%
# We validate the result
print('Train: X=%s, y=%s' % (x_train.shape, y_train.shape))
print('Test: X=%s, y=%s' % (x_test.shape, y_test.shape))
print('Validation: X=%s, y=%s' % (x_val.shape, y_val.shape))
# Out:
# Train: X=(40000, 32, 32, 3), y=(40000, 1)
# Test: X=(10000, 32, 32, 3), y=(10000, 1)
# Validation: X=(10000, 32, 32, 3), y=(10000, 1)

# %%
from tensorflow.keras.callbacks import EarlyStopping
callback_loss = EarlyStopping(monitor='val_loss', patience=5)
callback_accuracy = EarlyStopping(monitor='val_accuracy', patience=5)

# %% [markdown]
# Prepare the data

# %% [markdown]
# ## 5. Training
#
# We can start training the model! Be careful, we have to train against the data converted to the format expected by the Convolution.
#
# We will start with 30 epocs, that is, 30 complete passes of the dataset (which in turn will be with mini-batches internally), setting a batch of 64
#
# The .fit() method also allows us to define if we have several CPUs, GPUs, and if we want to validate data at each end of epoch.

# %%
t = time.perf_counter()

# %%
history = model.fit(x_train, y_train, epochs=30, 
                    use_multiprocessing=False, batch_size= 64, 
                    validation_data=(x_val, y_val),callbacks=[callback_accuracy, callback_loss]
                    )
# Out:
# Epoch 1/30
# 625/625 [==============================] - 18s 10ms/step - loss: 1.5227 - accuracy: 0.4698 - val_loss: 1.3046 - val_accuracy: 0.5552
# Epoch 2/30
# 625/625 [==============================] - 6s 10ms/step - loss: 1.0487 - accuracy: 0.6321 - val_loss: 0.9248 - val_accuracy: 0.6741
# Epoch 3/30
# 625/625 [==============================] - 6s 10ms/step - loss: 0.8532 - accuracy: 0.7067 - val_loss: 0.7446 - val_accuracy: 0.7408
# Epoch 4/30
# 625/625 [==============================] - 6s 10ms/step - loss: 0.7218 - accuracy: 0.7528 - val_loss: 0.9130 - val_accuracy: 0.6851
# Epoch 5/30
# 625/625 [==============================] - 6s 10ms/step - loss: 0.6460 - accuracy: 0.7800 - val_loss: 0.7309 - val_accuracy: 0.7566
# Epoch 6/30
# 625/625 [==============================] - 6s 10ms/step - loss: 0.5472 - accuracy: 0.8145 - val_loss: 0.6607 - val_accuracy: 0.7704
# Epoch 7/30
# 625/625 [==============================] - 6s 10ms/step - loss: 0.4848 - accuracy: 0.8333 - val_loss: 0.8024 - val_accuracy: 0.7428
# Epoch 8/30
# 625/625 [==============================] - 6s 10ms/step - loss: 0.4126 - accuracy: 0.8594 - val_loss: 0.6804 - val_accuracy: 0.7851
# Epoch 9/30
# 625/625 [==============================] - 6s 10ms/step - loss: 0.3697 - accuracy: 0.8725 - val_loss: 0.6549 - val_accuracy: 0.7996
# Epoch 10/30
# 625/625 [==============================] - 6s 10ms/step - loss: 0.3182 - accuracy: 0.8892 - val_loss: 0.8017 - val_accuracy: 0.7715
# Epoch 11/30
# 625/625 [==============================] - 6s 10ms/step - loss: 0.2728 - accuracy: 0.9043 - val_loss: 0.7980 - val_accuracy: 0.7829
# Epoch 12/30
# 625/625 [==============================] - 6s 10ms/step - loss: 0.2381 - accuracy: 0.9184 - val_loss: 0.7175 - val_accuracy: 0.8034
# Epoch 13/30
# 625/625 [==============================] - 6s 10ms/step - loss: 0.2192 - accuracy: 0.9262 - val_loss: 0.7624 - val_accuracy: 0.7947
# Epoch 14/30
# 625/625 [==============================] - 6s 10ms/step - loss: 0.1933 - accuracy: 0.9349 - val_loss: 0.7974 - val_accuracy: 0.8146

# %%
elapsed_time = datetime.timedelta(seconds=(time.perf_counter() - t))

print('Training time:', elapsed_time)
# Out:
# Training time: 0:04:14.391374

# %% [markdown]
# ## 6. We evaluate the results
#
# Let's obtain a graph of how the error and the accuracy evolve in each epoch in the training data and in the validation

# %% [markdown]
# # Model#1 Accurecy

# %%
_, acc = model.evaluate(x_test, y_test, verbose=0)
print('> %.3f' % (acc * 100.0))
# Out:
# > 80.550

# %% [markdown]
# # Model#2 Accurecy

# %%
_, acc = model.evaluate(x_test, y_test, verbose=0)
print('> %.3f' % (acc * 100.0))
# Out:
# > 75.580

# %% [markdown]
# # Model#3 Accurecy

# %%
_, acc = model.evaluate(x_test, y_test, verbose=0)
print('> %.3f' % (acc * 100.0))
# Out:
# > 80.250

# %% [markdown]
# # Model#4 Accurecy

# %%
_, acc = model.evaluate(x_test, y_test, verbose=0)
print('> %.3f' % (acc * 100.0))
# Out:
# > 68.280

# %% [markdown]
# # Model#5 Accurecy

# %%
_, acc = model.evaluate(x_test, y_test, verbose=0)
print('> %.3f' % (acc * 100.0))
# Out:
# > 76.860

# %%
# below are the results for the model 1 
plt.title('Cross Entropy Loss')
plt.plot(history.history['loss'], color='blue', label='train')
plt.plot(history.history['val_loss'], color='orange', label='val')
plt.legend()
plt.show()

plt.title('Classification Accuracy')
plt.plot(history.history['accuracy'], color='blue', label='train')
plt.plot(history.history['val_accuracy'], color='orange', label='val')
plt.legend()
plt.show()

# %% [markdown]
# The cost we can see that it is stable and it is in the epoch 15 that it is set at a value. Also the accuracy dances around 0.10. It cannot be said that it is a very good model.
#
# Let's see what kind of predictions I'm getting about the test set (let's paint the images and their classifications)

# %%
predictions = model.predict(x_test)

# %% [markdown]
# One of the advantages of Python is that there are loads of functions and code made by third parties. Here I have shot some nice functions (which I have adapted a bit to my needs) to be able to paint the images, their label (ground truth) and the classifications that we have made.

# %%
def plot_image(i, predictions_array, true_label, img):
    predictions_array, true_label, img = predictions_array, true_label[i], img[i]
    plt.grid(False)
    plt.xticks([])
    plt.yticks([])

    plt.imshow(img, cmap=plt.cm.binary)

    predicted_label = np.argmax(predictions_array)
    if predicted_label == true_label:
        color = 'blue'
    else:
        color = 'red'

    plt.xlabel("{} {:2.0f}% ({})".format(predicted_label,
                                100*np.max(predictions_array),
                                true_label[0]),
                                color=color)

def plot_value_array(i, predictions_array, true_label):
    predictions_array, true_label = predictions_array, true_label[i]
    plt.grid(False)
    plt.xticks(range(10))
    plt.yticks([])
    thisplot = plt.bar(range(10), predictions_array, color="#777777")
    plt.ylim([0, 1])
    predicted_label = np.argmax(predictions_array)

    thisplot[predicted_label].set_color('red')
    thisplot[true_label[0]].set_color('blue')

# %% [markdown]
# We draw the first images, with the predictions and their real values ​​(a total of 20 images, so as not to abuse your laptops)
#
# We color the correct predictions in blue and the failures in red. Although I have printed the labels first so that we have a reference to the graphic.

# %%
i = 0
for l in cifar10_labels:
    print(i, l)
    i += 1

num_rows = 5
num_cols = 4
start = 650
num_images = num_rows*num_cols
plt.figure(figsize=(2*2*num_cols, 2*num_rows))
for i in range(num_images):
    plt.subplot(num_rows, 2*num_cols, 2*i+1)
    plot_image(i+start, predictions[i+start], y_test, x_test)
    plt.subplot(num_rows, 2*num_cols, 2*i+2)
    plot_value_array(i+start, predictions[i+start], y_test)
plt.tight_layout()
plt.show()
# Out:
# 0 airplane
# 1 automobile
# 2 bird
# 3 cat
# 4 deer
# 5 dog
# 6 frog
# 7 horse
# 8 ship
# 9 truck

# %% [markdown]
# ## 7. We save the model for future evaluations
#
# Go changing the names of the file to save the various projects.
# Here we save it in "local", but remember that the ideal is that you save it in Google Drive (you have to mount the unit, set the path and save the .h5 model there)

# %%
model.save('cifar10_base_model.h5')
